# %%
#connect to gdrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#clone repo and install dependencies
# !git clone https://github.com/noahcao/OC_SORT.git
# %cd OC_SORT
# !pip3 install -r requirements.txt
# !python3 setup.py develop
# !pip3 install cython; pip3 install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip3 install cython_bbox pandas xmltodict
% dir
# Out:
# UsageError: Line magic function `%dir` not found.

# %%
# pre trained dance 
# %mkdir pretrained
# %cd pretrained
# !gdown 1Lox1HIT_HOOsPk6nKXuIwg46cap_S27t
# Out:
# /content/pretrained

# %%
# track sample video
# %cd ..
# !python3 tools/demo_track.py --demo_type video -f exps/example/mot/yolox_dancetrack_test.py -c pretrained/ocsort_dance_model.pth.tar --path videos/fish1.mp4 --fp16 --fuse --save_result --out_path fish1_out.mp4
# Out:
# /OC_SORT
