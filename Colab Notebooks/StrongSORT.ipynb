# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet.git  # clone repo
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.12.0+cu113 (CPU)

# %% [markdown]
# # Download data
#
# Get test video from repo and extract the first 2 seconds of it

# %%
# %cd /content/Yolov5_StrongSORT_OSNet
# %cd /content/Yolov5_StrongSORT_OSNet

# get yolov5m model trained on the crowd-human dataset
# !wget -nc https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet/releases/download/v.2.0/crowdhuman_yolov5m.pt -O /content/Yolov5_StrongSORT_OSNet/yolov5/crowdhuman_yolov5m.pt
# !gdown 1BF6iX5tF2iKqmY84G7yjQit7pgqw9ws2 -O /content/Yolov5_StrongSORT_OSNet/yolov5/
# !gdown 1Jn2RYxPW6p_j0DS3Lnfcu_HUKANwx7jB
# !tar -xvf annotate.tar


# get yolov5m model trained on the crowd-human dataset
# !wget -nc https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet/releases/download/v.2.0/crowdhuman_yolov5m.pt -O /content/Yolov5_StrongSORT_OSNet/yolov5/crowdhuman_yolov5m.pt

# !gdown 1BF6iX5tF2iKqmY84G7yjQit7pgqw9ws2 -O /content/Yolov5_StrongSORT_OSNet/yolov5/
# !gdown 1Jn2RYxPW6p_j0DS3Lnfcu_HUKANwx7jB
# !tar -xvf annotate.tar

# !gdown 1j_fzlfnDgq223mBdMuLJDFfh_7_NMxof -O /content/Yolov5_StrongSORT_OSNet/yolov5/yolox_x.pt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1j_fzlfnDgq223mBdMuLJDFfh_7_NMxof
# To: /content/Yolov5_StrongSORT_OSNet/yolov5/yolox_x.pt
# 100% 793M/793M [00:06<00:00, 122MB/s]

# %% [markdown]
# ## Run inference on video
#
# The ``cv2.imshow()`` and ``cv.imshow()`` functions from the [opencv-python](https://github.com/skvark/opencv-python) package are incompatible with Jupyter notebook; see https://github.com/jupyter/notebook/issues/3935.
#
# Hence we chose to save it to file in this notebook. Locally you can use the ``--show-vid`` flag in order visualize the tracking in real-time

# %%
# %cd content/Yolov5_StrongSORT_OSNet/
# !pip install -U PyYAML
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/crowdhuman_yolov5m.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source fishraw1.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/crowdhuman_yolov5m.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source fishraw2.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/crowdhuman_yolov5m.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source fishraw3.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/crowdhuman_yolov5m.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source fishraw4.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/crowdhuman_yolov5m.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A031.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/crowdhuman_yolov5m.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A032.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/crowdhuman_yolov5m.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A030.mp4 --save-vid --classes 0 --save-txt 


# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5s.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A031.mp4 --save-vid --classes 0 --save-txt 


# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5s.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A031.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5s.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A032.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5s.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A033.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5s.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A030.mp4 --save-vid --classes 0 --save-txt 

# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5l.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A031.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5l.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A032.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5l.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A033.mp4 --save-vid --classes 0 --save-txt 
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5l.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A030.mp4 --save-vid --classes 0 --save-txt 



# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolox_x.pt --strong-sort-weights osnet_x0_25_msmt17.pt --source annotate/ds0/video/A030.mp4 --save-vid --classes 0 --save-txt
# Out:
# strong_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# track: yolo_weights=['/content/Yolov5_StrongSORT_OSNet/yolov5/yolox_x.pt'], strong_sort_weights=osnet_x0_25_msmt17.pt, config_strongsort=strong_sort/configs/strong_sort.yaml, source=annotate/ds0/video/A030.mp4, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=True, save_conf=False, save_crop=False, save_vid=True, nosave=False, classes=[0], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False
# requirements: tb-nightly not found and is required by YOLOv5, attempting auto-update...
# ...

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# Convert avi to mp4

# %%
# !ffmpeg -i /content/Yolov5_StrongSORT_OSNet/runs/track/exp/out.mp4 output.mp4
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %% [markdown]
# Get the file content into data_url

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-014fc7e00255> in <module>()
#       1 from IPython.display import HTML
#       2 from base64 import b64encode
# ----> 3 mp4 = open('output.mp4','rb').read()
#       4 data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output.mp4'

# %% [markdown]
# Display it with HTML

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
