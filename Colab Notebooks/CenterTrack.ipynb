# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:24
# 🔁 Restarting kernel...

# %%
# !conda install pytorch torchvision -c pytorch
# !pip install cython; pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !git clone --recursive https://github.com/xingyizhou/CenterTrack $CenterTrack_ROOT
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     blas-2.106                 |              mkl          12 KB  conda-forge
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     certifi-2022.6.15          |   py37h89c1867_0         155 KB  conda-forge
#     conda-4.13.0               |   py37h89c1867_1         989 KB  conda-forge
#     cudatoolkit-11.1.1         |       h6406543_8        1.20 GB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     jpeg-9e                    |       h166bdaf_2         269 KB  conda-forge
#     libblas-3.9.0              |            6_mkl          11 KB  conda-forge
#     libcblas-3.9.0             |            6_mkl          11 KB  conda-forge
#     libgcc-ng-12.1.0           |      h8d9b700_16         940 KB  conda-forge
#     libgfortran-ng-12.1.0      |      h69a702a_16          23 KB  conda-forge
#     libgfortran5-12.1.0        |      hdcd56e2_16         1.8 MB  conda-forge
#     liblapack-3.9.0            |            6_mkl          11 KB  conda-forge
#     liblapacke-3.9.0           |            6_mkl          11 KB  conda-forge
#     libpng-1.6.37              |       h753d276_3         331 KB  conda-forge
#     libtiff-4.0.10             |    hc3755c2_1005         602 KB  conda-forge
#     libzlib-1.2.12             |       h166bdaf_2          63 KB  conda-forge
#     llvm-openmp-14.0.4         |       he0ac6c6_0         5.8 MB  conda-forge
#     mkl-2020.4                 |     h726a3e6_304       215.6 MB  conda-forge
#     numpy-1.20.3               |   py37h3e96413_2         5.7 MB  conda-forge
#     olefile-0.46               |     pyh9f0ad1d_1          32 KB  conda-forge
#     openssl-1.1.1q             |       h166bdaf_0         2.1 MB  conda-forge
#     pillow-6.2.1               |   py37h6b7be26_0         637 KB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     pytorch-1.12.1             |      py3.7_cpu_0        76.6 MB  pytorch
#     pytorch-mutex-1.0          |              cpu           3 KB  pytorch
#     torchvision-0.2.2          |             py_3          44 KB  pytorch
#     typing_extensions-4.3.0    |     pyha770c72_0          28 KB  conda-forge
#     zlib-1.2.12                |       h166bdaf_2          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.51 GB
#
# The following NEW packages will be INSTALLED:
#
#   blas               conda-forge/linux-64::blas-2.106-mkl
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.1.1-h6406543_8
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   jpeg               conda-forge/linux-64::jpeg-9e-h166bdaf_2
#   libblas            conda-forge/linux-64::libblas-3.9.0-6_mkl
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-6_mkl
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.1.0-h69a702a_16
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.1.0-hdcd56e2_16
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-6_mkl
#   liblapacke         conda-forge/linux-64::liblapacke-3.9.0-6_mkl
#   libpng             conda-forge/linux-64::libpng-1.6.37-h753d276_3
#   libtiff            conda-forge/linux-64::libtiff-4.0.10-hc3755c2_1005
#   libzlib            conda-forge/linux-64::libzlib-1.2.12-h166bdaf_2
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-14.0.4-he0ac6c6_0
#   mkl                conda-forge/linux-64::mkl-2020.4-h726a3e6_304
#   numpy              conda-forge/linux-64::numpy-1.20.3-py37h3e96413_2
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   pillow             conda-forge/linux-64::pillow-6.2.1-py37h6b7be26_0
#   pytorch            pytorch/linux-64::pytorch-1.12.1-py3.7_cpu_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cpu
#   torchvision        pytorch/noarch::torchvision-0.2.2-py_3
#   typing_extensions  conda-forge/noarch::typing_extensions-4.3.0-pyha770c72_0
#
# The following packages will be REMOVED:
#
#   libgomp-9.3.0-h2828fa1_18
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.12.5-ha878542_0 --> 2022.6.15-ha878542_0
#   certifi                          2020.12.5-py37h89c1867_1 --> 2022.6.15-py37h89c1867_0
#   conda                                4.9.2-py37h89c1867_0 --> 4.13.0-py37h89c1867_1
#   libgcc-ng                               9.3.0-h2828fa1_18 --> 12.1.0-h8d9b700_16
#   openssl                                 1.1.1j-h7f98852_0 --> 1.1.1q-h166bdaf_0
#   python_abi                                    3.7-1_cp37m --> 3.7-2_cp37m
#   zlib                                 1.2.11-h516909a_1010 --> 1.2.12-h166bdaf_2
#
# The following packages will be DOWNGRADED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 4.5-2_kmp_llvm
#
#
#
# Downloading and Extracting Packages
# zlib-1.2.12          | 91 KB     | : 100% 1.0/1 [00:00<00:00,  9.95it/s]
# torchvision-0.2.2    | 44 KB     | : 100% 1.0/1 [00:00<00:00,  2.70it/s]
# numpy-1.20.3         | 5.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.10s/it]
# pillow-6.2.1         | 637 KB    | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
# blas-2.106           | 12 KB     | : 100% 1.0/1 [00:00<00:00,  3.39it/s]
# pytorch-mutex-1.0    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 30.19it/s]
# openssl-1.1.1q       | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
# ca-certificates-2022 | 149 KB    | : 100% 1.0/1 [00:00<00:00, 20.31it/s]
# certifi-2022.6.15    | 155 KB    | : 100% 1.0/1 [00:00<00:00, 17.92it/s]
# libtiff-4.0.10       | 602 KB    | : 100% 1.0/1 [00:00<00:00,  8.19it/s]
# jpeg-9e              | 269 KB    | : 100% 1.0/1 [00:00<00:00, 11.57it/s]
# libgfortran-ng-12.1. | 23 KB     | : 100% 1.0/1 [00:00<00:00, 28.15it/s]
# libgfortran5-12.1.0  | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  3.33it/s]
# pytorch-1.12.1       | 76.6 MB   | : 100% 1.0/1 [02:37<00:00, 157.06s/it]
# freetype-2.10.4      | 890 KB    | : 100% 1.0/1 [00:00<00:00,  5.50it/s]
# mkl-2020.4           | 215.6 MB  | : 100% 1.0/1 [00:35<00:00, 35.65s/it]
# _openmp_mutex-4.5    | 6 KB      | : 100% 1.0/1 [00:00<00:00, 20.74it/s]
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 29.78it/s]
# cudatoolkit-11.1.1   | 1.20 GB   | : 100% 1.0/1 [02:36<00:00, 156.71s/it]
# libpng-1.6.37        | 331 KB    | : 100% 1.0/1 [00:00<00:00,  7.80it/s]
# libblas-3.9.0        | 11 KB     | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# conda-4.13.0         | 989 KB    | : 100% 1.0/1 [00:00<00:00,  4.52it/s]
# liblapack-3.9.0      | 11 KB     | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
# typing_extensions-4. | 28 KB     | : 100% 1.0/1 [00:00<00:00, 25.79it/s]
# libcblas-3.9.0       | 11 KB     | : 100% 1.0/1 [00:00<00:00,  3.35it/s]
# olefile-0.46         | 32 KB     | : 100% 1.0/1 [00:00<00:00, 26.48it/s]
# libgcc-ng-12.1.0     | 940 KB    | : 100% 1.0/1 [00:00<00:00,  5.71it/s]
# libzlib-1.2.12       | 63 KB     | : 100% 1.0/1 [00:00<00:00, 22.41it/s]
# liblapacke-3.9.0     | 11 KB     | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
# llvm-openmp-14.0.4   | 5.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.21it/s]
# done
# done
# | By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cython
#   Downloading Cython-0.29.32-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 32.3 MB/s
# Installing collected packages: cython
# Successfully installed cython-0.29.32
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-rtbdhho1
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-rtbdhho1
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.7/site-packages (from pycocotools==2.0) (49.6.0.post20210108)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.7/site-packages (from pycocotools==2.0) (0.29.32)
# Collecting matplotlib>=2.1.0
#   Downloading matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 34.5 MB/s
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.20.3)
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 70.8 MB/s
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 52.5 MB/s
# Collecting packaging>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.6 MB/s
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (6.2.1)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 7.6 MB/s
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      |████████████████████████████████| 944 kB 54.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.1.0->pycocotools==2.0) (4.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.15.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=273125 sha256=573372232699adde2ff0313ad3ffcde54101bf9c87b166ad3371f214ea0a62d0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-90cte4au/wheels/e2/6b/1d/344ac773c7495ea0b85eb228bc66daec7400a143a92d36b7b1
# Successfully built pycocotools
# Installing collected packages: pyparsing, python-dateutil, packaging, kiwisolver, fonttools, cycler, matplotlib, pycocotools
# Successfully installed cycler-0.11.0 fonttools-4.34.4 kiwisolver-1.4.4 matplotlib-3.5.2 packaging-21.3 pycocotools-2.0 pyparsing-3.0.9 python-dateutil-2.8.2
# Cloning into 'CenterTrack'...
# remote: Enumerating objects: 285, done.
# remote: Total 285 (delta 0), reused 0 (delta 0), pack-reused 285
# Receiving objects: 100% (285/285), 15.01 MiB | 16.33 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# %cd CenterTrack
# !pip install -r requirements.txt
# Out:
# /content/CenterTrack
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      |████████████████████████████████| 60.9 MB 1.2 MB/s
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.29.32)
# Collecting numba
#   Downloading numba-0.56.0-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 70.7 MB/s
# Collecting progress
#   Downloading progress-1.6.tar.gz (7.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (3.5.2)
# Collecting easydict
#   Downloading easydict-1.9.tar.gz (6.4 kB)
# Collecting scipy
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# Collecting pyquaternion
#   Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Collecting nuscenes-devkit
#   Downloading nuscenes_devkit-1.1.9-py3-none-any.whl (312 kB)
#      |████████████████████████████████| 312 kB 76.9 MB/s
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 59.7 MB/s
# Collecting motmetrics
#   Downloading motmetrics-1.2.5-py3-none-any.whl (161 kB)
#      |████████████████████████████████| 161 kB 49.3 MB/s
# Collecting scikit-learn==0.22.2
#   Downloading scikit_learn-0.22.2-cp37-cp37m-manylinux1_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 10.7 MB/s
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn==0.22.2->-r requirements.txt (line 12)) (1.20.3)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 69.3 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 5)) (4.34.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 5)) (6.2.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->-r requirements.txt (line 5)) (4.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 5)) (1.15.0)
# Collecting pandas>=0.23.1
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 64.0 MB/s
# Collecting xmltodict>=0.12.0
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting pytz>=2017.3
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 76.4 MB/s
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      |████████████████████████████████| 34.6 MB 1.2 MB/s
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from numba->-r requirements.txt (line 3)) (49.6.0.post20210108)
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 67.5 MB/s
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 7.3 MB/s
# Collecting Shapely
#   Downloading Shapely-1.8.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 62.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/site-packages (from nuscenes-devkit->-r requirements.txt (line 9)) (4.59.0)
# Collecting pycocotools>=2.0.1
#   Downloading pycocotools-2.0.4.tar.gz (106 kB)
#      |████████████████████████████████| 106 kB 75.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting descartes
#   Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Collecting cachetools
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Collecting ipykernel
#   Downloading ipykernel-6.15.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 74.0 MB/s
# Collecting notebook
#   Downloading notebook-6.4.12-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 60.9 MB/s
# Collecting jupyter-console
#   Downloading jupyter_console-6.4.4-py3-none-any.whl (22 kB)
# Collecting ipywidgets
#   Downloading ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 77.3 MB/s
# Collecting nbconvert
#   Downloading nbconvert-6.5.1-py3-none-any.whl (563 kB)
#      |████████████████████████████████| 563 kB 69.1 MB/s
# Collecting qtconsole
#   Downloading qtconsole-5.3.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 73.7 MB/s
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.5-py3-none-any.whl (5.2 kB)
# Collecting matplotlib-inline>=0.1
#   Downloading matplotlib_inline-0.1.3-py3-none-any.whl (8.2 kB)
# Collecting tornado>=6.1
#   Downloading tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
#      |████████████████████████████████| 423 kB 63.5 MB/s
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-7.3.4-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 72.2 MB/s
# Collecting debugpy>=1.0
#   Downloading debugpy-1.6.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 65.8 MB/s
# Collecting traitlets>=5.1.0
#   Downloading traitlets-5.3.0-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 77.8 MB/s
# Collecting pyzmq>=17
#   Downloading pyzmq-23.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 69.1 MB/s
# Collecting ipython>=7.23.1
#   Downloading ipython-7.34.0-py3-none-any.whl (793 kB)
#      |████████████████████████████████| 793 kB 65.2 MB/s
# Collecting psutil
#   Downloading psutil-5.9.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#      |████████████████████████████████| 281 kB 73.1 MB/s
# Collecting decorator
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 60.1 MB/s
# Collecting pexpect>4.3
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.9 MB/s
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.30-py3-none-any.whl (381 kB)
#      |████████████████████████████████| 381 kB 75.6 MB/s
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting pygments
#   Downloading Pygments-2.12.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 69.5 MB/s
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 11.9 MB/s
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting jupyter-core>=4.9.2
#   Downloading jupyter_core-4.11.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 9.1 MB/s
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 60.2 MB/s
# Collecting ipython-genutils~=0.2.0
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
#      |████████████████████████████████| 245 kB 77.9 MB/s
# Collecting terminado>=0.8.3
#   Downloading terminado-0.15.0-py3-none-any.whl (16 kB)
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.14.1-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.0 MB/s
# Collecting nbformat
#   Downloading nbformat-5.4.0-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 1.9 MB/s
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 77.1 MB/s
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 67.3 MB/s
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.6.6-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 202 kB/s
# Collecting tinycss2
#   Downloading tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Collecting bleach
#   Downloading bleach-5.0.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 68.2 MB/s
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting lxml
#   Downloading lxml-4.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 30.7 MB/s
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.1-py3-none-any.whl (22 kB)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.9.1-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.2 MB/s
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#      |████████████████████████████████| 117 kB 78.4 MB/s
# Collecting attrs>=17.4.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.9 MB/s
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.4 MB/s
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->nuscenes-devkit->-r requirements.txt (line 9)) (1.14.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->nuscenes-devkit->-r requirements.txt (line 9)) (2.20)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.1.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 6.3 MB/s
# Building wheels for collected packages: easydict, pycocotools, progress, fire, termcolor
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6350 sha256=d4addea00b089bdfbb37e0d890ca14d9c45098c1f30aa46a893a24783edae855
#   Stored in directory: /root/.cache/pip/wheels/88/96/68/c2be18e7406804be2e593e1c37845f2dd20ac2ce1381ce40b0
#   Building wheel for pycocotools (PEP 517) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.4-cp37-cp37m-linux_x86_64.whl size=273788 sha256=801c62c5be7abbed57e41bb93a5ac6a62930ccfc714526fb674bf55b1e3ab1bd
#   Stored in directory: /root/.cache/pip/wheels/a3/5f/fa/f011e578cc76e1fc5be8dce30b3eb9fd00f337e744b3bba59b
#   Building wheel for progress (setup.py) ... done
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9614 sha256=bd98aace02f6ee4f87975275f2d82b5ae7cddbea4c5a826f52cd04d7b0b16ec6
#   Stored in directory: /root/.cache/pip/wheels/8e/d7/61/498d8e27dc11e9805b01eb3539e2ee344436fc226daeb5fe87
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=af01d491108a0864c2b8de49b079fe798d07393933a2b947e46435656dfaf36b
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=413574d8bed2446ebd577740c1a98016a2507ba4cd22dd9dde9c37e567a4f826
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built easydict pycocotools progress fire termcolor
# Installing collected packages: zipp, traitlets, pyrsistent, pkgutil-resolve-name, importlib-resources, importlib-metadata, attrs, wcwidth, tornado, pyzmq, ptyprocess, parso, nest-asyncio, jupyter-core, jsonschema, fastjsonschema, entrypoints, webencodings, soupsieve, pygments, prompt-toolkit, pickleshare, pexpect, nbformat, matplotlib-inline, MarkupSafe, jupyter-client, jedi, decorator, backcall, tinycss2, psutil, pandocfilters, nbclient, mistune, lxml, jupyterlab-pygments, jinja2, ipython, defusedxml, debugpy, bleach, beautifulsoup4, argon2-cffi-bindings, terminado, Send2Trash, prometheus-client, nbconvert, ipython-genutils, ipykernel, argon2-cffi, notebook, widgetsnbextension, qtpy, pillow, jupyterlab-widgets, termcolor, scipy, qtconsole, pytz, jupyter-console, joblib, ipywidgets, xmltodict, Shapely, scikit-learn, pyquaternion, pycocotools, pandas, opencv-python, llvmlite, jupyter, fire, descartes, cachetools, pyyaml, progress, nuscenes-devkit, numba, motmetrics, easydict
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 6.2.1
#     Uninstalling Pillow-6.2.1:
#       Successfully uninstalled Pillow-6.2.1
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0
#     Uninstalling pycocotools-2.0:
#       Successfully uninstalled pycocotools-2.0
# Successfully installed MarkupSafe-2.1.1 Send2Trash-1.8.0 Shapely-1.8.2 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 attrs-22.1.0 backcall-0.2.0 beautifulsoup4-4.11.1 bleach-5.0.1 cachetools-5.2.0 debugpy-1.6.2 decorator-5.1.1 defusedxml-0.7.1 descartes-1.1.0 easydict-1.9 entrypoints-0.4 fastjsonschema-2.16.1 fire-0.4.0 importlib-metadata-4.12.0 importlib-resources-5.9.0 ipykernel-6.15.1 ipython-7.34.0 ipython-genutils-0.2.0 ipywidgets-7.7.1 jedi-0.18.1 jinja2-3.1.2 joblib-1.1.0 jsonschema-4.9.1 jupyter-1.0.0 jupyter-client-7.3.4 jupyter-console-6.4.4 jupyter-core-4.11.1 jupyterlab-pygments-0.2.2 jupyterlab-widgets-1.1.1 llvmlite-0.39.0 lxml-4.9.1 matplotlib-inline-0.1.3 mistune-0.8.4 motmetrics-1.2.5 nbclient-0.6.6 nbconvert-6.5.1 nbformat-5.4.0 nest-asyncio-1.5.5 notebook-6.4.12 numba-0.56.0 nuscenes-devkit-1.1.9 opencv-python-4.6.0.66 pandas-1.3.5 pandocfilters-1.5.0 parso-0.8.3 pexpect-4.8.0 pickleshare-0.7.5 pillow-9.2.0 pkgutil-resolve-name-1.3.10 progress-1.6 prometheus-client-0.14.1 prompt-toolkit-3.0.30 psutil-5.9.1 ptyprocess-0.7.0 pycocotools-2.0.4 pygments-2.12.0 pyquaternion-0.9.9 pyrsistent-0.18.1 pytz-2022.1 pyyaml-6.0 pyzmq-23.2.0 qtconsole-5.3.1 qtpy-2.1.0 scikit-learn-0.22.2 scipy-1.7.3 soupsieve-2.3.2.post1 termcolor-1.1.0 terminado-0.15.0 tinycss2-1.1.1 tornado-6.2 traitlets-5.3.0 wcwidth-0.2.5 webencodings-0.5.1 widgetsnbextension-3.6.1 xmltodict-0.13.0 zipp-3.8.1

# %%
# %cd src/lib/model/networks/
# !git clone https://github.com/CharlesShang/DCNv2/ # clone if it is not automatically downloaded by `--recursive`.
# %cd DCNv2
# Out:
# /content/CenterTrack/src/lib/model/networks
# Cloning into 'DCNv2'...
# remote: Enumerating objects: 214, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 214 (delta 47), reused 36 (delta 36), pack-reused 155
# Receiving objects: 100% (214/214), 1.40 MiB | 34.23 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# /content/CenterTrack/src/lib/model/networks/DCNv2

# %%
# !python setup.py build develop
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running build
# running build_ext
# /usr/local/lib/python3.7/site-packages/torch/utils/cpp_extension.py:411: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# building '_ext' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/content
# creating build/temp.linux-x86_64-3.7/content/CenterTrack
# creating build/temp.linux-x86_64-3.7/content/CenterTrack/src
# creating build/temp.linux-x86_64-3.7/content/CenterTrack/src/lib
# creating build/temp.linux-x86_64-3.7/content/CenterTrack/src/lib/model
# creating build/temp.linux-x86_64-3.7/content/CenterTrack/src/lib/model/networks
# creating build/temp.linux-x86_64-3.7/content/CenterTrack/src/lib/model/networks/DCNv2
# creating build/temp.linux-x86_64-3.7/content/CenterTrack/src/lib/model/networks/DCNv2/src
# creating build/temp.linux-x86_64-3.7/content/CenterTrack/src/lib/model/networks/DCNv2/src/cpu
# g++ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/content/CenterTrack/src/lib/model/networks/DCNv2/src -I/usr/local/lib/python3.7/site-packages/torch/include -I/usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/site-packages/torch/include/TH -I/usr/local/lib/python3.7/site-packages/torch/include/THC -I/usr/local/include/python3.7m -c /content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.cpp -o build/temp.linux-x86_64-3.7/content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_ext -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# In file included from /content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.cpp:2:0:
# /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h: In function ‘at::Tensor dcn_v2_forward(const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, int, int, int, int, int, int, int, int, int)’:
# /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h:25:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#      if (input.type().is_cuda())
#                     ^
# In file included from /usr/local/lib/python3.7/site-packages/torch/include/ATen/core/Tensor.h:3:0,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/ATen/ATen.h:11,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/extension.h:4,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/cpu/vision.h:2,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h:3,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.cpp:2:
# /usr/local/lib/python3.7/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.cpp:2:0:
# /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h: In function ‘std::vector<at::Tensor> dcn_v2_backward(const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, int, int, int, int, int, int, int, int, int)’:
# /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h:61:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#      if (input.type().is_cuda())
#                     ^
# In file included from /usr/local/lib/python3.7/site-packages/torch/include/ATen/core/Tensor.h:3:0,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/ATen/ATen.h:11,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/extension.h:4,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/cpu/vision.h:2,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h:3,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.cpp:2:
# /usr/local/lib/python3.7/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.cpp:2:0:
# /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h: In function ‘std::tuple<at::Tensor, at::Tensor> dcn_v2_psroi_pooling_forward(const at::Tensor&, const at::Tensor&, const at::Tensor&, int, float, int, int, int, int, int, float)’:
# /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h:107:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#      if (input.type().is_cuda())
#                     ^
# In file included from /usr/local/lib/python3.7/site-packages/torch/include/ATen/core/Tensor.h:3:0,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/ATen/ATen.h:11,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/extension.h:4,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/cpu/vision.h:2,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h:3,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.cpp:2:
# /usr/local/lib/python3.7/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.cpp:2:0:
# /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h: In function ‘std::tuple<at::Tensor, at::Tensor> dcn_v2_psroi_pooling_backward(const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, int, float, int, int, int, int, int, float)’:
# /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h:155:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#      if (input.type().is_cuda())
#                     ^
# In file included from /usr/local/lib/python3.7/site-packages/torch/include/ATen/core/Tensor.h:3:0,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/ATen/ATen.h:11,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /usr/local/lib/python3.7/site-packages/torch/include/torch/extension.h:4,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/cpu/vision.h:2,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/dcn_v2.h:3,
#                  from /content/CenterTrack/src/lib/model/networks/DCNv2/src/vision.cpp:2:
# /usr/local/lib/python3.7/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# g++ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/content/CenterTrack/src/lib/model/networks/DCNv2/src -I/usr/local/lib/python3.7/site-packages/torch/include -I/usr/local/lib/python3.7/site-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/site-packages/torch/include/TH -I/usr/local/lib/python3.7/site-packages/torch/include/THC -I/usr/local/include/python3.7m -c /content/CenterTrack/src/lib/model/networks/DCNv2/src/cpu/dcn_v2_psroi_pooling_cpu.cpp -o build/temp.linux-x86_64-3.7/content/CenterTrack/src/lib/model/networks/DCNv2/src/cpu/dcn_v2_psroi_pooling_cpu.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_ext -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# /content/CenterTrack/src/lib/model/networks/DCNv2/src/cpu/dcn_v2_psroi_pooling_cpu.cpp:18:10: fatal error: TH/TH.h: No such file or directory
#  #include <TH/TH.h>
#           ^~~~~~~~~
# compilation terminated.
# error: command 'g++' failed with exit status 1
