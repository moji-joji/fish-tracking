# %%
# !git clone https://github.com/1vpmaster/SimpleTrack.git
# Out:
# fatal: destination path 'SimpleTrack' already exists and is not an empty directory.

# %%
# %cd SimpleTrack
# !gdown 1pl_-ael8wERdUREEnaIfqOV_VF2bEVRT
# !gdown 1t6BYhkZlx7CUnkTIsVHEQLIhVzDDh8mn
# Out:
# /content/SimpleTrack
# Downloading...
# From: https://drive.google.com/uc?id=1pl_-ael8wERdUREEnaIfqOV_VF2bEVRT
# To: /content/SimpleTrack/ctdet_coco_dla_2x.pth
# 100% 80.9M/80.9M [00:00<00:00, 185MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1t6BYhkZlx7CUnkTIsVHEQLIhVzDDh8mn
# To: /content/SimpleTrack/SimpleTrack.pth
# 100% 281M/281M [00:01<00:00, 197MB/s]

# %%
# !conda --version
# Out:
# /bin/bash: conda: command not found

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:56
# 🔁 Restarting kernel...

# %%
# !conda install pytorch==1.4.0 torchvision==0.5.0 cudatoolkit=10.1 -c pytorch
# !conda install pytorch==1.7.1 torchvision==0.8.2 cudatoolkit=10.1 -c pytorch
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# / WARNING conda.core.solve:_add_specs(649): pinned spec cudatoolkit=11.1 conflicts with explicit specs.  Overriding pinned spec.
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - pytorch==1.4.0
#     - torchvision==0.5.0
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   pytorch            conda-forge::pytorch-1.7.1-cpu_py37hf~ --> pytorch::pytorch-1.4.0-py3.7_cuda10.1.243_cudnn7.6.3_0
#   torchvision        conda-forge::torchvision-0.8.2-py37h6~ --> pytorch::torchvision-0.5.0-py37_cu101
#
#
# done
# done
# done

# %%
# !pip install cython
# !pip install cython_bbox
# !pip install scipy
# !pip install seaborn
# !pip install -r requirements.txt --user
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.9 MB 33.1 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 244 kB/s
# ...
#   Created wheel for cython-bbox: filename=cython_bbox-0.1.3-cp37-cp37m-linux_x86_64.whl size=60584 sha256=897d8d443b0e18608bbd17ccbe483cedc5e4ae802d7b6d881e29727e8acaae2b
#   Stored in directory: /root/.cache/pip/wheels/51/82/21/5def8bc98ae4ea436d7f0decb7194d20d7e3e6d0578a4129d7
# Successfully built cython-bbox
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 292 kB 34.6 MB/s
# ...

# %%
# !git clone https://github.com/CharlesShang/DCNv2
# %cd DCNv2
# Out:
# /content/SimpleTrack/DCNv2

# %%
# !python setup.py build develop --user
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running build
# running build_ext
# building '_ext' extension
# Emitting ninja build file /content/SimpleTrack/DCNv2/build/temp.linux-x86_64-3.7/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ...

# %%
# %cd ..
# %cd src
# !dir
# Out:
# A030.mp4		dists.jpg	  src
# assets			experiments	  tools
# build			README.md	  TrackEval-master
# condacolab_install.log	requirements.txt  tutorials
# ctdet_coco_dla_2x.pth	results
# DCNv2			SimpleTrack.pth

# %%
# !python src/demo.py mot --load_model ctdet_coco_dla_2x.pth --input-video A030.mp4 --output-format video --arch dla_34
# Out:
# Fix size testing.
# training chunk_sizes: [4]
# The output will be saved to  /content/SimpleTrack/src/lib/../../exp/mot/default
# heads {'hm': 1, 'wh': 4, 'id': 128, 'reg': 2}
# 2022-08-09 14:06:03 [INFO]: Starting tracking...
# Lenth of the video: 169 frames
# Creating model...
# loaded ctdet_coco_dla_2x.pth, epoch 230
# Skip loading parameter hm.2.weight, required shapetorch.Size([1, 256, 1, 1]), loaded shapetorch.Size([80, 256, 1, 1]). If you see this, your model does not fully load the pre-trained weight. Please make sure you have correctly specified --arch xxx or set the correct --num_classes for your own dataset.
# Skip loading parameter hm.2.bias, required shapetorch.Size([1]), loaded shapetorch.Size([80]). If you see this, your model does not fully load the pre-trained weight. Please make sure you have correctly specified --arch xxx or set the correct --num_classes for your own dataset.
# ...

# %%
# !python3 src/demo.py --ds
# Out:
# usage: demo.py [-h] [--dataset DATASET] [--exp_id EXP_ID] [--test]
#                [--load_model LOAD_MODEL] [--resume] [--gpus GPUS]
#                [--num_workers NUM_WORKERS] [--not_cuda_benchmark]
#                [--seed SEED] [--print_iter PRINT_ITER] [--hide_data_time]
#                [--save_all] [--metric METRIC] [--vis_thresh VIS_THRESH]
#                [--arch ARCH] [--head_conv HEAD_CONV] [--down_ratio DOWN_RATIO]
#                [--input_res INPUT_RES] [--input_h INPUT_H] [--input_w INPUT_W]
#                [--lr LR] [--lr_step LR_STEP] [--num_epochs NUM_EPOCHS]
#                [--batch_size BATCH_SIZE]
#                [--master_batch_size MASTER_BATCH_SIZE] [--num_iters NUM_ITERS]
#                [--val_intervals VAL_INTERVALS] [--trainval]
#                [--memory_enable MEMORY_ENABLE]
#                [--local_frame_dist LOCAL_FRAME_DIST]
#                [--local_frame_num LOCAL_FRAME_NUM]
#                [--memory_frame_dist MEMORY_FRAME_DIST]
# ...
