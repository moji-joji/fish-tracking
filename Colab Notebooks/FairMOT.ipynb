# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:28
# 🔁 Restarting kernel...

# %%
# !conda install pytorch==1.7.0 torchvision==0.8.0 cudatoolkit=10.2 -c pytorch
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# | WARNING conda.core.solve:_add_specs(611): pinned spec cudatoolkit=11.1 conflicts with explicit specs.  Overriding pinned spec.
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.2
#     - pytorch==1.7.0
#     - torchvision==0.8.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     blas-2.110                 |              mkl          12 KB  conda-forge
#     blas-devel-3.9.0           |           10_mkl          11 KB  conda-forge
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     certifi-2022.6.15          |   py37h89c1867_0         155 KB  conda-forge
# ...

# %%
# !git clone https://github.com/ifzhang/FairMOT.git
# %cd FairMOT
# Out:
# Cloning into 'FairMOT'...
# remote: Enumerating objects: 719, done.
# remote: Total 719 (delta 0), reused 0 (delta 0), pack-reused 719
# Receiving objects: 100% (719/719), 63.34 MiB | 32.20 MiB/s, done.
# Resolving deltas: 100% (383/383), done.
# /content/FairMOT/FairMOT

# %%
# !pip install cython
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.9 MB 9.6 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 60.9 MB 96 kB/s
# ...
#      |████████████████████████████████| 596 kB 68.9 MB/s
# ...
#      |████████████████████████████████| 41 kB 295 kB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 161 kB 66.6 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 71.4 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 62.1 MB/s
# ...
#      |████████████████████████████████| 242 kB 65.0 MB/s
# ...
#      |████████████████████████████████| 125 kB 71.0 MB/s
# ...
#      |████████████████████████████████| 50 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 247 kB 46.0 MB/s
# ...

# %%
# !git clone -b pytorch_1.7 https://github.com/ifzhang/DCNv2.git
# %cd DCNv2
# !python setup.py build develop
# %cd ..
# %mkdir models
# %cd models
# !gdown 1HVzDTrYSSZiVqExqG9rou3zZXX1
# Out:
# Cloning into 'DCNv2'...
# remote: Enumerating objects: 263, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 263 (delta 77), reused 64 (delta 64), pack-reused 171
# Receiving objects: 100% (263/263), 1.42 MiB | 21.07 MiB/s, done.
# Resolving deltas: 100% (167/167), done.
# /content/FairMOT/FairMOT/DCNv2
# running build
# running build_ext
# building '_ext' extension
# creating /content/FairMOT/FairMOT/DCNv2/build
# creating /content/FairMOT/FairMOT/DCNv2/build/temp.linux-x86_64-3.7
# creating /content/FairMOT/FairMOT/DCNv2/build/temp.linux-x86_64-3.7/content
# creating /content/FairMOT/FairMOT/DCNv2/build/temp.linux-x86_64-3.7/content/FairMOT
# creating /content/FairMOT/FairMOT/DCNv2/build/temp.linux-x86_64-3.7/content/FairMOT/FairMOT
# creating /content/FairMOT/FairMOT/DCNv2/build/temp.linux-x86_64-3.7/content/FairMOT/FairMOT/DCNv2
# ...

# %%
# !python src/demo.py mot --load_model models/mot20_fairmot.pth --conf_thres 0.5 --input-video videos/A030.mp4 --output-root out/30/
# !python src/demo.py mot --load_model models/mot20_fairmot.pth --conf_thres 0.5 --input-video videos/A031.mp4 --output-root out/31/
# !python src/demo.py mot --load_model models/mot20_fairmot.pth --conf_thres 0.5 --input-video videos/A032.mp4 --output-root out/32/
# !python src/demo.py mot --load_model models/mot20_fairmot.pth --conf_thres 0.5 --input-video videos/A033.mp4 --output-root out/33/
# !python src/demo.py mot --load_model models/mot20_fairmot.pth --conf_thres 0.5 --input-video videos/A034.mp4 --output-root out/34/
# Out:
# Fix size testing.
# training chunk_sizes: [6, 6]
# The output will be saved to  /content/FairMOT/FairMOT/src/lib/../../exp/mot/default
# heads {'hm': 1, 'wh': 4, 'id': 128, 'reg': 2}
# 2022-08-09 10:02:14 [INFO]: Starting tracking...
# Lenth of the video: 169 frames
# Creating model...
# loaded models/mot20_fairmot.pth, epoch 30
# 2022-08-09 10:02:17 [INFO]: Processing frame 0 (100000.00 fps)
# 2022-08-09 10:02:20 [INFO]: Processing frame 20 (11.95 fps)
# 2022-08-09 10:02:22 [INFO]: Processing frame 40 (13.29 fps)
# 2022-08-09 10:02:25 [INFO]: Processing frame 60 (13.81 fps)
# 2022-08-09 10:02:28 [INFO]: Processing frame 80 (14.09 fps)
# 2022-08-09 10:02:30 [INFO]: Processing frame 100 (14.22 fps)
# 2022-08-09 10:02:33 [INFO]: Processing frame 120 (14.30 fps)
# 2022-08-09 10:02:36 [INFO]: Processing frame 140 (14.37 fps)
# 2022-08-09 10:02:38 [INFO]: Processing frame 160 (14.39 fps)
# 2022-08-09 10:02:40 [INFO]: save results to out/30/results.txt
# ...

# %%
# !zip -r fairmot.zip out
# Out:
#   adding: out/ (stored 0%)
#   adding: out/33/ (stored 0%)
#   adding: out/33/results.txt (deflated 54%)
#   adding: out/33/videoResult.mp4 (deflated 4%)
#   adding: out/33/frame/ (stored 0%)
#   adding: out/33/frame/00069.jpg (deflated 0%)
#   adding: out/33/frame/00080.jpg (deflated 0%)
#   adding: out/33/frame/00065.jpg (deflated 0%)
#   adding: out/33/frame/00034.jpg (deflated 0%)
#   adding: out/33/frame/00105.jpg (deflated 0%)
#   adding: out/33/frame/00045.jpg (deflated 0%)
#   adding: out/33/frame/00090.jpg (deflated 0%)
#   adding: out/33/frame/00076.jpg (deflated 0%)
#   adding: out/33/frame/00078.jpg (deflated 0%)
#   adding: out/33/frame/00100.jpg (deflated 0%)
#   adding: out/33/frame/00101.jpg (deflated 0%)
#   adding: out/33/frame/00064.jpg (deflated 0%)
#   adding: out/33/frame/00058.jpg (deflated 0%)
#   adding: out/33/frame/00084.jpg (deflated 0%)
#   adding: out/33/frame/00093.jpg (deflated 0%)
#   adding: out/33/frame/00002.jpg (deflated 0%)
# ...
